# %% [markdown]
# # Audience Segmentation

# %% [markdown]
# ## Set-up: Import + Config

# %%
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer, util
# Out:
# C:\Users\ek102\.conda\envs\audience-segmentation\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# ## Load data

# %% [markdown]
# Set file path according to location of CSV. Tip: Find the file using the left sidebar, click the three dots for more options, and copy the path.

# %%
dataset_file_path = "./PBL_DA_FA24_CAPSTONE_DATA.csv"

# %% [markdown]
# Detect CSV's encoding format using `chardet` library ... because this CSV has weird encoding

# %%
import chardet

with open(dataset_file_path, 'rb') as f:
    chardet_result = chardet.detect(f.read())
print(chardet_result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# Load the CSV.

# %%
df = pd.read_csv(dataset_file_path, encoding=chardet_result['encoding'])
df.head()
# Out:
#                                     Audience Segment Creative Size  \
# 0  Online Behavior>United States>Validated Demogr...       300x250
# 1  Online Behavior>United States>Finance Â» Finan...        320x50
# 2  Online Behavior>United States>Hobbies and Leis...       300x250
# 3  Online Behavior>United States>Intent Â» Auto B...       300x250
# 4  Online Behavior>United States>Beauty and Fitne...       300x250
#
#                Creative Messaging                          Location  \
# 0  Subscribe Today - 10% Discount           Los Angeles, California
# 1         Sign up Today - 10% Off    Orlando-Daytona Beach, Florida
# 2  Subscribe Today - 10% Discount         San Francisco, California
# 3           Sign up Now - 10% Off  Grand Rapids-Kalamazoo, Michigan
# 4           Sign up Now - 10% Off                 Chicago, Illinois
#
#            App/URL                         Exchange Device Make Impressions  \
# 0   abcnews.go.com                Google Ad Manager    Apple PC       10524
# 1  accuweather.com                         PubMatic  Smartphone       18324
# 2  accuweather.com                Google Ad Manager  Smartphone        7862
# 3  accuweather.com  Xandr - Monetize SSP (AppNexus)  Smartphone       10501
# 4  accuweather.com                      Magnite DV+    Apple PC       23156
#
#    Clicks Viewable Impressions Measurable Impressions  Total Conversions  \
# 0    55.0                 7601                  10242               11.0
# 1    60.0                 3145                  13703                8.0
# 2    20.0                 2152                   6039                2.0
# 3    90.0                 4126                   7654                8.0
# 4    73.0                 4468                  18821               15.0
#
#     Gross Cost
# 0  6136.133902
# 1  6996.231838
# 2  6506.433687
# 3  6244.517921
# 4  6173.412890

# %% [markdown]
# Inspect `Audience Segment` column more closely. Notice formatting issues (e.g., Â» instead of >).

# %%
df["Audience Segment"].head()
# Out:
# 0    Online Behavior>United States>Validated Demogr...
# 1    Online Behavior>United States>Finance Â» Finan...
# 2    Online Behavior>United States>Hobbies and Leis...
# 3    Online Behavior>United States>Intent Â» Auto B...
# 4    Online Behavior>United States>Beauty and Fitne...
# Name: Audience Segment, dtype: object

# %% [markdown]
# ## Data cleansing

# %% [markdown]
# ### Remove null rows

# %%
# Filter rows where "Audience Segment" is NaN
nan_rows = df[df['Audience Segment'].isna()]
nan_rows
# Out:
#     Audience Segment Creative Size Creative Messaging Location App/URL  \
# 727              NaN           NaN                NaN      NaN     NaN
# 728              NaN           NaN                NaN      NaN     NaN
#
#     Exchange Device Make Impressions  Clicks Viewable Impressions  \
# 727      NaN         NaN         NaN     NaN                  NaN
# 728      NaN         NaN         NaN     NaN                  NaN
#
#     Measurable Impressions  Total Conversions  Gross Cost
# 727                    NaN                NaN         NaN
# 728                    NaN                NaN         NaN

# %%
# Remove rows with NaN values in the "Audience Segment" column
df = df.dropna(subset=['Audience Segment'])

# %% [markdown]
# ### Clean up delimiter (>)

# %%
# Clean up the 'Â»' character (and standardize surrounding whitespace)
df['Audience Segment'] = df['Audience Segment'].str.replace('Â»', '>', regex=False)
df['Audience Segment'] = df['Audience Segment'].str.replace('»', '>', regex=False)
df['Audience Segment'] = df['Audience Segment'].str.replace(' > ', '>', regex=False)
df['Audience Segment'] = df['Audience Segment'].str.replace('>', ' > ', regex=False)
df['Audience Segment']
# Out:
# 0      Online Behavior > United States > Validated De...
# 1      Online Behavior > United States > Finance > Fi...
# 2      Online Behavior > United States > Hobbies and ...
# 3      Online Behavior > United States > Intent > Aut...
# 4      Online Behavior > United States > Beauty and F...
#                              ...
# 722    US > Brand Propensities > Automotive > Ford Cr...
# 723    US Technology > Social Media > Likely Behavior...
# 724    US > B2B > B2B Decision Maker Responsibilities...
# 725                  Transactional > Q3 Fashion Shoppers
# 726    Lotame > Style, Fashion & Clothing > Men's Clo...
# Name: Audience Segment, Length: 727, dtype: object

# %% [markdown]
# ### Create tokens

# %%
# Example code for preprocessing
df['tokens'] = df['Audience Segment'].apply(lambda x: [token.strip() for token in x.split('>')])
df['tokens']
# Out:
# 0      [Online Behavior, United States, Validated Dem...
# 1      [Online Behavior, United States, Finance, Fina...
# 2      [Online Behavior, United States, Hobbies and L...
# 3      [Online Behavior, United States, Intent, Auto ...
# 4      [Online Behavior, United States, Beauty and Fi...
#                              ...
# 722    [US, Brand Propensities, Automotive, Ford Cred...
# 723    [US Technology, Social Media, Likely Behavior,...
# 724    [US, B2B, B2B Decision Maker Responsibilities,...
# 725                 [Transactional, Q3 Fashion Shoppers]
# 726    [Lotame, Style, Fashion & Clothing, Men's Clot...
# Name: tokens, Length: 727, dtype: object

# %% [markdown]
# #### Eliminate noisy tokens

# %%
noise_tokens = ['United States', 'US', 'Online Behavior', 'Interest',
                'Propensity Models', 'Intent', 'validated', 'Reach', 'OnAudience',
                'ConneXions', 'Brands', 'The Changing Consumer', 'Lotame',
                'Mobile - US', 'Brand Propensities']

# %%
# Remove noise tokens from each token list
df['tokens'] = df['tokens'].apply(lambda tokens: [token for token in tokens if token not in noise_tokens])

# Display filtered tokens to verify
df['tokens']
# Out:
# 0      [Validated Demographic, Gender and Age Combine...
# 1      [Finance, Financial Planning and Management, R...
# 2            [Hobbies and Leisure, Outdoors, Equestrian]
# 3                        [Auto Buyers, Car Make, Audi Q]
# 4      [Beauty and Fitness, Fitness, Fitness Instruct...
#                              ...
# 722           [Automotive, Ford Credit Buyer Propensity]
# 723    [US Technology, Social Media, Likely Behavior,...
# 724    [B2B, B2B Decision Maker Responsibilities, Rea...
# 725                 [Transactional, Q3 Fashion Shoppers]
# 726    [Style, Fashion & Clothing, Men's Clothing Sho...
# Name: tokens, Length: 727, dtype: object

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Initialize Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

def get_weighted_embedding(text):
    # Tokenize by splitting on '>'
    tokens = [token.strip() for token in text.split('>') if token.strip()]
    n = len(tokens)  # Number of tokens

    # Generate embeddings and weights
    weighted_embeddings = []
    for i, token in enumerate(tokens):
        embedding = model.encode(token)

        # Calculate weight: proportional to position (closer to leaf = higher weight)
        weight = (i + 1) / n  # You can experiment with different weighting schemes here
        weighted_embeddings.append(embedding * weight)

    # Sum the weighted embeddings to get the final embedding
    final_embedding = np.sum(weighted_embeddings, axis=0)
    return final_embedding

# Apply the function to each category in your DataFrame
df['weighted_embeddings'] = df['Audience Segment'].apply(get_weighted_embedding)

# Convert list of embeddings to a 2D array
X = np.array(df['weighted_embeddings'].tolist())

# Perform clustering
from sklearn.cluster import KMeans
num_clusters = 10  # Adjust based on your data
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Display results by cluster
for cluster_num in sorted(df['cluster'].unique()):
    print(f"Cluster {cluster_num + 1}:")
    cluster_items = df[df['cluster'] == cluster_num]['Audience Segment']
    for item in cluster_items:
        print(f"- {item}")
    print()
# Out:
# Cluster 1:
# - US > B2B > B2B Decision Maker Responsibilities > Purchasing Utilities
# - Online Behavior > United States > B2B > Occupation > Musician
# - US > B2B > B2B Decision Maker Responsibilities > Financial Services
# - Online Behavior > United States > B2B > Occupation > MechanicalEngineer
# - Online Behavior > United States > Law and Government > Public Safety
# - Online Behavior > United States > Jobs and Education > Education
# - US > B2B > Purchase DM > Technology Services, Hardware and > or Software > I have no input into the final decision
# - Online Behavior > United States > The Changing Consumer > Internet Connection
# - Online Behavior > United States > Intent > Shopping > Consumer Electronics > Computers, Laptops
# - Online Behavior > United States > Law and Government > Military
# - US > B2B > B2B Decision Maker Responsibilities > Company Liability or Insurance
# - US > B2B > B2B Decision Maker Responsibilities > Employee Benefits
# - Online Behavior > United States > The Changing Consumer > Gaming Equipment
# - Online Behavior > United States > B2B > Occupation > OfficeManager
# - Online Behavior > United States > Internet and Telecom > Email and Messaging
# - US > B2B > B2B Decision Maker Responsibilities > Advertising Services
# - US > B2B > B2B Decision Maker Responsibilities > Accounting or Tax Services
# - Online Behavior > United States > Intent > Shopping > Drug Stores > CVS
# - Online Behavior > United States > B2B > Occupation > Student
# - Online Behavior > United States > Online Communities > File Sharing and Hosting
# - US > B2B > B2B Decision Maker Responsibilities > Office Supplies or Equipment
# - Online Behavior > United States > B2B > Occupation > SystemsAnalyst
# - Online Behavior > United States > The Changing Consumer > Active Facebook Users
# - US > B2B > B2B Decision Maker Responsibilities > Computer Hardware
# - Online Behavior > United States > Online Communities > Social Networks
# - Online Behavior > United States > Online Communities > Photo and Video Sharing
# - Online Behavior > United States > Internet and Telecom > Mobile and Wireless
# - US > B2B > B2B Decision Maker Responsibilities > Marketing or Market Research
# - US > B2B > B2B Decision Maker Responsibilities > HR or Personnel Services
# - US > B2B > B2B Decision Maker Responsibilities > Sales
# - Online Behavior > United States > Intent > Shopping > Consumer Electronics > Cameras and Photography Equip
# - Online Behavior > United States > The Changing Consumer > B2B Work from Home
# - OnAudience > Interest > Technology & Computing > Internet Technology
# - Online Behavior > United States > B2B > Occupation > Teacher
# - US > B2B > B2B Decision Maker Responsibilities > Computer Software
# - Online Behavior > United States > The Changing Consumer > Data For Good > Current Affairs - Social Justice
# - Online Behavior > United States > The Changing Consumer > Personal Budgeting
# - Online Behavior > United States > B2B > Occupation > ElectricalEngineer
# - Online Behavior > United States > Intent > Shopping > Wireless Providers
# - US > Interest Propensities > Activities and Interests > B2B Job Search
# - Online Behavior > United States > B2B > Occupation > SupplyChainManager
# - Online Behavior > United States > The Changing Consumer > Natural Disasters
# - US > Reach > Propensity Models > Online > Home Office
# - Online Behavior > United States > Online Communities > Online Goodies
# - Online Behavior > United States > Jobs and Education > Jobs
# - US > B2B > B2B Decision Maker Responsibilities > Internet Services
# - US > B2B > Purchase DM > Technology Services, Hardware and > or Software > I am the sole decision maker
# - Online Behavior > United States > The Changing Consumer > CPG
# - Online Behavior > United States > Internet and Telecom > Web Apps and Online Tools
# - Online Behavior > United States > Internet and Telecom > Web Services
# - Online Behavior > United States > B2B > Occupation > ComputerProgrammer
# - US > B2B > B2B Decision Maker Responsibilities > Office Services or Moving
# - US > Reach > Propensity Models > Online > Electronics and Gadgets
# - Online Behavior > United States > Online Communities > Blogging Resources and Services
# - Online Behavior > United States > The Changing Consumer > Telehealth
# - Online Behavior > United States > Law and Government > Government
# - US > B2B > B2B Decision Maker Responsibilities > Security Services
# - US Financial > Likely Credit Card > Behavior > Used for Personal Purposes
# - Online Behavior > United States > The Changing Consumer > Streaming Services
# - US > B2B > B2B Decision Maker Responsibilities > Television providers > services
# - US > B2B > Purchase DM > Technology Services, Hardware and > or Software > I make the final decision with input from staff > management
# - Online Behavior > United States > B2B > Occupation > Broker
# - Online Behavior > United States > The Changing Consumer > DIY
# - Online Behavior > United States > Life Event > Job Search
# - US > B2B > B2B Decision Maker Responsibilities > Print, Copy or Photo Services
# - Mobile - US > Gamers > Online > Users
# - Online Behavior > United States > Law and Government > Legal
# - Online Behavior > United States > B2B > Occupation > Entrepreneur
# - Online Behavior > United States > Online Communities > Dating and Personals
# - Online Behavior > United States > Internet and Telecom > Search Engines
# - Online Behavior > United States > Internet and Telecom > Web Portals
# - US > Reach > Propensity Models > Online > Pets
# - Online Behavior > United States > The Changing Consumer > Home Learning
# - Online Behavior > United States > B2B > Occupation > PropertyManager
# - Online Behavior > United States > The Changing Consumer > Virtual Events
# - US > B2B > B2B Decision Maker Responsibilities > Purchasing Vehicles or Automobile Services
# - Online Behavior > United States > B2B > Occupation > Architect
# - US > B2B > B2B Decision Maker Responsibilities > Real Estate Services
#
# Cluster 2:
# - Online Behavior > United States > Hobbies and Leisure > Outdoors > Equestrian
# - US > Interest Propensities > TV and Movies > Sports TV
# - OnAudience > Intent > Electronics > Video > Televisions
# - Online Behavior > United States > Arts and Entertainment > Events and Listings > Bars, Clubs and Nightlife
# - US > Interest Propensities > Activities and Interests > Local News
# - US > Home and Garden Interests > Cooking > Food Enthusiasts
# - US > Interest Propensities > Music > Country
# - Online Behavior > United States > Games > Computer and Video Games
# - US > Reach > Propensity Models > Hobbies and Interest > Food and Drinks >
or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-64
# - Online Behavior > United States > Validated Demographic > Age > 25-34
# - Online Behavior > United States > Validated Demographic > Age > 18-54
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 18-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 18-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-54
# - Online Behavior > United States > Validated Demographic > Age > 25-64
# - US > Demo > Age > 65+
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-34
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 55-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-44
# - Online Behavior > United States > Validated Demographic > Age > 18 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 55-64
# - Online Behavior > United States > Validated Demographic > Age > 65 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25 or older
# - Online Behavior > United States > Validated Demographic > Age > 25-54
# - US Demographic > Age > Specialty Age Range > 21+
# - Online Behavior > United States > Validated Demographic > Gender > Female
#
# Cluster 7:
# - Lotame > Travel > Summer Travel
# - Online Behavior > United States > Travel > Specialty Travel > Adventure Travel
# - Online Behavior > United States > Travel > Tourist Destinations > Zoos-Aquariums-Preserves
# - Mobile - US > Travel > Destination > International Travelers > Frequent Travelers
# - Travel and Tourism > Interest (Affinity) > Destinations > North America
# - Online Behavior > United States > Travel > Bus and Rail
# - Travel and Tourism > Interest (Affinity) > Destinations > North America > United States
# - Online Behavior > United States > Travel > Tourist Destinations > Regional Parks and Gardens
# - Online Behavior > United States > Travel > Tourist Destinations > Mountain and Ski Resorts
# - Online Behavior > United States > Travel > Tourist Destinations > Beaches and Islands
# - Online Behavior > United States > Travel > Travel
# - Online Behavior > United States > Intent > Travel > Accommodation > Hotels
# - Online Behavior > United States > Travel > Car Rental and Taxi Services
# - Online Behavior > United States > Intent > Travel > Cruises
# - Online Behavior > United States > Travel > Tourist Destinations
# - Online Behavior > United States > Travel > Cruises and Charters
# - Mobile - US > Travel > Car Rentals > Hertz
# - Lotame > Travel > International Travel
# - Travel and Tourism > Interest (Affinity) > Destinations > Latin America
# - Online Behavior > United States > Travel > Air Travel
# - Online Behavior > United States > Travel > Tourist Destinations > Lakes and Rivers
# - Mobile - US > Travel > Vacation Rentals > HomeAway
# - Online Behavior > United States > Intent > Travel > Business Travel
# - Mobile - US > Travel > Activity > Ski Travelers
# - Lotame > Travel > Winter Holiday Travel
# - Online Behavior > United States > Travel > Air Travel > Airport Parking and Transportation
# - Mobile - US > Travel > Destination > International Travelers > yes
# - Travel and Tourism > Interest (Affinity) > Destinations > Europe
# - Online Behavior > United States > Travel > Travel Agencies and Services
# - Online Behavior > United States > Travel > Specialty Travel > Agritourism
# - OnAudience > Interest > Travel
# - Online Behavior > United States > Travel > Business Travel
# - OnAudience > Intent > Travel
# - Online Behavior > United States > Travel > Travel Agencies and Services > Tourist Boards and Visitor Centers
# - US > Reach > Propensity Models > Travel > High Frequency Travel > Foreign Vacationer
# - Online Behavior > United States > Intent > Travel > Flights
# - Online Behavior > United States > Travel > Hotels and Accommodations
# - Online Behavior > United States > Intent > Travel > Graduation Trip
# - US Travel > Likely Business Travel > Number of Nights Stayed > 0 Nights
# - Online Behavior > United States > Intent > Travel > Luxury Travel
# - Online Behavior > United States > Travel > Tourist Destinations > Historical Sites and Buildings
# - Online Behavior > United States > Travel > Carpooling and Vehicle Sharing
# - Online Behavior > United States > Travel > Specialty Travel
# - Online Behavior > United States > Intent > Travel > Future Travel
# - Online Behavior > United States > Travel > Travel Guides and Travelogues
# - Lotame > Travel > Thanksgiving Travel
# - Travel and Tourism > Interest (Affinity) > Destinations > Africa
# - Travel
# - Online Behavior > United States > Intent > Travel > Travel
# - Online Behavior > United States > Intent > Travel > Budget Travel
# - Travel and Tourism > Interest (Affinity) > Products > Air Travel
# - Online Behavior > United States > Travel > Tourist Destinations >
# - Media and Entertainment > Sports and Recreational Activities > Interest (Affinity)
# - OnAudience
# - Media and Entertainment > Audio and Video Streaming > Streaming Audio
# - US  > Rural Improvement Fanatic
# - Media and Entertainment > Music
# - OnAudience > Interest > Technology
# - US > Interest Propensities > Social > Premium User Generated Content
# - Telecommunications (Telco) > Subscribers
# - Mobile - US > Device Ownership > Smartphones > Huawei
# - US > Composite Segment > Women Born to Shop
# - Real Estate > Rent Amount > Sensible  Rentals ($1000-$3000)
# - US > AUTO > Decision Maker for Auto Purchase > I shared equally in the decision
# - OnAudience > Interest > Life Stage
# - Mobile - US > Device Ownership > Smartphones > ZTE
# - Transactional > Q2 Graduation Gift Shoppers
# - Media and Entertainment > Consumer Entertainment Technology
# - US Interest > Cooking > General
# - US Financial > Estimated Disposable Income > $0 - $99,999
# - Online Behavior > United States > News > Technology News
# - Online Behavior > United States > News > Business News
# - US > Premium Entertainment and Pastimes > Premium Magazine Enthusiasts
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > iPhone X
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > iPhone 11
# - Real Estate > Sale Activity > Just Sold
# - US Interest > Consumer Electronics
# - US > Interest Propensities > Insurance > Unitedhealth Group
# - US > Interest Propensities > Insurance > Aetna Group
# - OnAudience > Interest > News > Local News
# - US > Response Performance > Direct Marketing Purchasers
# - OnAudience > Interest > News > National News
# - Media Source
# - US > Sociodemographic > P$YCLE Premier Lifestage > M3 Upscale Empty Nests
# - OnAudience > Intent > Education
# - Mobile - US > Sports > UFC Fans
# - Lotame > Technology > Mobile Phones
# - Mobile - US > Device Ownership > Smartphones > Vivo
# - Lotame > Technology > Electronics & Gadgets
# - OnAudience > Intent > Toys & Games
# - Lotame > Technology
# - Lotame > Offline CPG Purchasers > Product Segment
# - Transactional > Q3 Home Entertainers
# - US Financial > Likely In Market Timing > Not At All Likely to Purchase > Second House/Residence In The Next Year (Financial)
# - Mobile - US > Device Ownership > Tablets > yes
# - US > Interest Propensities > Celebrities > Celebrity Fan Gossip
# - US > Interest Propensities > Insurance > Humana
# - Media and Entertainment > Gaming > In-Market
# - Media and Entertainment > Events and Attractions
# - US > Sociodemographic > P$YCLE Premier Lifestage > Y3 Fiscal Fledglings
# - OnAudience > Interest > News & Magazines
# - Lotame > Social Media
# - US > Financially in Charge > Performance Score: Top 25%
# - Media and Entertainment > News and Current Events
# - OnAudience > Interest > Shopping
# - Media and Entertainment > News and Current Events > Online News Websites
# - Tech Enthusiasts
# - US Interest > Computers
# - Media and Entertainment > Audio and Video Streaming > Streaming Video > Interest (Affinity)
# - OnAudience > Interest > Science > Weather
# - Online Behavior > United States > The Changing Consumer > Trending TV Shows
# - OnAudience > Interest > News
# - Transactional > Q3 Casual Dining Restaurant Goers
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > yes
# - OnAudience > Interest > Education
# - OnAudience > Intent > Software
# - OnAudience > Intent > Baby & Toddler > Baby Toys
# - Media and Entertainment > Television (TV)
# - Online Behavior > United States > News > Local News
# - Travel and Tourism > In-Market
# - Telecommunications and Mobile Tech > Mobile Devices and Connected Technology
# - US > Sociodemographic > PRIZM Premier Social > C2 City Centers
# - OnAudience > Intent > Electronics > Video Game Consoles
# - Lotame > Style, Fashion & Clothing
# - Purchase-Based
# - OnAudience > Interest > Social life
# - US  > Price-Driven Traditionalist Audience
# - US > Sociodemographic > ConneXions Lifestage > Y2 Emerging Techies
# - US Financial > Likely In Market Timing > Not At All Likely to Purchase > First Home/Residence In The Next Year (Financial)
# - Transactional > Q3 Gardening Shoppers
# - OnAudience > Intent
# - OnAudience > Interest > Pets
# - OnAudience > Interest > Technology & Computing > Email
# - Media and Entertainment > Connected TV and Over-the-Top (CTV and OTT)
# - OnAudience > Interest > Society
# - Mobile - US > Automotive > Repair & Oil Change > Intend
# - Restaurants
# - OnAudience > Interest
# - Media Source > LBDigital > Open For Business B2B
# - OnAudience > Intent > Baby & Toddler
# - US Buying Channel Preference > Online
# - US  > Made In America Audience
# - Purchase Behaviors > Q2 Spring Cleaners
# - US > Sociodemographic > PRIZM Premier Lifestage > F2 Young Accumulators
# - Online Behavior > United States > The Changing Consumer > Pet Adoption
# - Media and Entertainment
# - Retail
# - US > Financially in Charge > Performance Score: Top 50%
# - US > Interest Propensities > Insurance > Lincoln Heritage
# - US Mail Order Buyer
# - OnAudience > Interest > News > International News
# - US Financial > Likely Attitude and Behavior > Completely Disagree > When I Find A Financial Product/Service I Like I Typically Recommend It To People I Know (Financial)
# - US Financial > Method of Payment > Other
# - US  > Quality-First Shopper Audience
# - US Demographic > Preferred Language > Non-Hispanic
# - Online Behavior > United States > News > Weather
# - Media and Entertainment > Television (TV) > Viewership
# - US > Interest Propensities > Activities and Interests > Ecommerce
# - OnAudience > Interest > Technology & Computing
# - Media and Entertainment > Audio and Video Streaming > Streaming Video
# - US > AUTO > Decision Maker for Auto Purchase > I was the sole decision-maker
# - Media and Entertainment > Audio and Video Streaming > Streaming Video > Interest (Affinity) > Streaming Services
# - US > Interest Propensities > Insurance > Transamerica
# - Media & Entertainment
# - Travel and Tourism > Interest (Affinity)
# - US Technology > Social Media > Likely Behavior > Heavy Facebook User
# - Transactional > Q3 Fashion Shoppers
# C:\Users\ek102\.conda\envs\audience-segmentation\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# Initialize Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

def get_weighted_embedding(text):
    # Tokenize by splitting on '>'
    tokens = [token.strip() for token in text.split('>') if token.strip()]
    n = len(tokens)  # Number of tokens

    # Generate embeddings and weights
    weighted_embeddings = []
    for i, token in enumerate(tokens):
        embedding = model.encode(token)

        # Calculate weight: proportional to position (closer to leaf = higher weight)
        weight = (i + 1) / n  # You can experiment with different weighting schemes here
        weighted_embeddings.append(embedding * weight)

    # Sum the weighted embeddings to get the final embedding
    final_embedding = np.sum(weighted_embeddings, axis=0)
    return final_embedding

# Apply the function to each category in your DataFrame
df['weighted_embeddings'] = df['Audience Segment'].apply(get_weighted_embedding)

# Convert list of embeddings to a 2D array
X = np.array(df['weighted_embeddings'].tolist())

# Perform clustering
num_clusters = 10  # Adjust based on your data
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Find representative label for each cluster
def find_representative_label(cluster_df):
    # Calculate the centroid of the cluster
    cluster_center = np.mean(np.array(cluster_df['weighted_embeddings'].tolist()), axis=0)

    # Find the item closest to the cluster center
    similarities = cosine_similarity([cluster_center], np.array(cluster_df['weighted_embeddings'].tolist()))
    closest_idx = similarities.argmax()

    # Get the representative item as the label
    representative_label = cluster_df.iloc[closest_idx]['Audience Segment']
    return representative_label

# Apply the function to each cluster to get the representative label
cluster_labels = {}
for cluster_num in df['cluster'].unique():
    cluster_df = df[df['cluster'] == cluster_num]
    cluster_label = find_representative_label(cluster_df)
    cluster_labels[cluster_num] = cluster_label

# Add the cluster label to the DataFrame
df['cluster_label'] = df['cluster'].map(cluster_labels)

# Display results by cluster with labels
for cluster_num in sorted(df['cluster'].unique()):
    print(f"Cluster {cluster_num + 1}: ({df[df['cluster'] == cluster_num]['cluster_label'].iloc[0]})")
    cluster_items = df[df['cluster'] == cluster_num]['Audience Segment']
    for item in cluster_items:
        print(f"- {item}")
    print()
# Out:
# Cluster 1: (US > B2B > B2B Decision Maker Responsibilities > Television providers > services)
# - US > B2B > B2B Decision Maker Responsibilities > Purchasing Utilities
# - Online Behavior > United States > B2B > Occupation > Musician
# - US > B2B > B2B Decision Maker Responsibilities > Financial Services
# - Online Behavior > United States > B2B > Occupation > MechanicalEngineer
# - Online Behavior > United States > Law and Government > Public Safety
# - Online Behavior > United States > Jobs and Education > Education
# - US > B2B > Purchase DM > Technology Services, Hardware and > or Software > I have no input into the final decision
# - Online Behavior > United States > The Changing Consumer > Internet Connection
# - Online Behavior > United States > Intent > Shopping > Consumer Electronics > Computers, Laptops
# - Online Behavior > United States > Law and Government > Military
# - US > B2B > B2B Decision Maker Responsibilities > Company Liability or Insurance
# - US > B2B > B2B Decision Maker Responsibilities > Employee Benefits
# - Online Behavior > United States > The Changing Consumer > Gaming Equipment
# - Online Behavior > United States > B2B > Occupation > OfficeManager
# - Online Behavior > United States > Internet and Telecom > Email and Messaging
# - US > B2B > B2B Decision Maker Responsibilities > Advertising Services
# - US > B2B > B2B Decision Maker Responsibilities > Accounting or Tax Services
# - Online Behavior > United States > Intent > Shopping > Drug Stores > CVS
# - Online Behavior > United States > B2B > Occupation > Student
# - Online Behavior > United States > Online Communities > File Sharing and Hosting
# - US > B2B > B2B Decision Maker Responsibilities > Office Supplies or Equipment
# - Online Behavior > United States > B2B > Occupation > SystemsAnalyst
# - Online Behavior > United States > The Changing Consumer > Active Facebook Users
# - US > B2B > B2B Decision Maker Responsibilities > Computer Hardware
# - Online Behavior > United States > Online Communities > Social Networks
# - Online Behavior > United States > Online Communities > Photo and Video Sharing
# - Online Behavior > United States > Internet and Telecom > Mobile and Wireless
# - US > B2B > B2B Decision Maker Responsibilities > Marketing or Market Research
# - US > B2B > B2B Decision Maker Responsibilities > HR or Personnel Services
# - US > B2B > B2B Decision Maker Responsibilities > Sales
# - Online Behavior > United States > Intent > Shopping > Consumer Electronics >
online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-64)
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-54
# - Online Behavior > United States > Validated Demographic > Age > 55-64
# - US > Demo > Age > 55-64
# - US > Premium Gender > Premium Gender > Males
# - Online Behavior > United States > Validated Demographic > Age > 18-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 45-54
# - Online Behavior > United States > Validated Demographic > Age > 25-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 18-54
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 35-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 65 or older
# - US > Reach > Sociodemographic > Age > 45-49
# - Online Behavior > United States > Validated Demographic > Age > 35-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25-34
# - Online Behavior > United States > Validated Demographic > Gender > Male
# - Online Behavior > United States > Validated Demographic > Age > 25 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-64
# - Online Behavior > United States > Validated Demographic > Age > 25-34
# - Online Behavior > United States > Validated Demographic > Age > 18-54
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 18-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 18-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-54
# - Online Behavior > United States > Validated Demographic > Age > 25-64
# - US > Demo > Age > 65+
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-34
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 55-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Females 25-44
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 18-44
# - Online Behavior > United States > Validated Demographic > Age > 18 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25-64
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 55-64
# - Online Behavior > United States > Validated Demographic > Age > 65 or older
# - Online Behavior > United States > Validated Demographic > Gender and Age Combined > Males 25 or older
# - Online Behavior > United States > Validated Demographic > Age > 25-54
# - US Demographic > Age > Specialty Age Range > 21+
# - Online Behavior > United States > Validated Demographic > Gender > Female
#
# Cluster 7: (Online Behavior > United States > Travel > Travel)
# - Lotame > Travel > Summer Travel
# - Online Behavior > United States > Travel > Specialty Travel > Adventure Travel
# - Online Behavior > United States > Travel > Tourist Destinations > Zoos-Aquariums-Preserves
# - Mobile - US > Travel > Destination > International Travelers > Frequent Travelers
# - Travel and Tourism > Interest (Affinity) > Destinations > North America
# - Online Behavior > United States > Travel > Bus and Rail
# - Travel and Tourism > Interest (Affinity) > Destinations > North America > United States
# - Online Behavior > United States > Travel > Tourist Destinations > Regional Parks and Gardens
# - Online Behavior > United States > Travel > Tourist Destinations > Mountain and Ski Resorts
# - Online Behavior > United States > Travel > Tourist Destinations > Beaches and Islands
# - Online Behavior > United States > Travel > Travel
# - Online Behavior > United States > Intent > Travel > Accommodation > Hotels
# - Online Behavior > United States > Travel > Car Rental and Taxi Services
# - Online Behavior > United States > Intent > Travel > Cruises
# - Online Behavior > United States > Travel > Tourist Destinations
# - Online Behavior > United States > Travel > Cruises and Charters
# - Mobile - US > Travel > Car Rentals > Hertz
# - Lotame > Travel > International Travel
# - Travel and Tourism > Interest (Affinity) > Destinations > Latin America
# - Online Behavior > United States > Travel > Air Travel
# - Online Behavior > United States > Travel > Tourist Destinations > Lakes and Rivers
# - Mobile - US > Travel > Vacation Rentals > HomeAway
# - Online Behavior > United States > Intent > Travel > Business Travel
# - Mobile - US > Travel > Activity > Ski Travelers
# - Lotame > Travel > Winter Holiday Travel
# - Online Behavior > United States > Travel > Air Travel > Airport Parking and Transportation
# - Mobile - US > Travel > Destination > International Travelers > yes
# - Travel and Tourism > Interest (Affinity) > Destinations > Europe
# - Online Behavior > United States > Travel > Travel Agencies and Services
# - Online Behavior > United States > Travel > Specialty Travel > Agritourism
# - OnAudience > Interest > Travel
# - Online Behavior > United States > Travel > Business Travel
# - OnAudience > Intent > Travel
# - Online Behavior > United States > Finance > Banking > Debit and Checking Services
# - Online Behavior > United States > Finance > Banking > Savings Accounts
# - US > Interest Propensities > Activities and Interests > Buying and Selling Homes > Real Estate
# - Online Behavior > United States > Intent > Financial Intent > Insurance > Auto
# - Online Behavior > United States > Finance > Insurance > Travel Insurance
# - Online Behavior > United States > Finance > Accounting and Auditing > Accounting and Auditing
#
# Cluster 10: (OnAudience > Interest > Business)
# - OnAudience > Intent > Software > Video Game Software
# - OnAudience > Intent > Animals & Pet
# - US > Multibuyer Behaviors > Paid with Credit Card
# - US > Response Performance > Direct Marketing Responders
# - US > Interest Propensities > Insurance > MassMutual
# - Online Behavior > United States > News > Sports News
# - Telecommunications (Telco)
# - OnAudience > Interest > Careers
# - OnAudience > Interest > Science > Weather Forecast
# - US  > Connected Impulse-Shopper Audience
# - Online Behavior > United States > News > Newspapers
# - OnAudience > Intent > Sporting Goods
# - US > Interest Propensities > Oil & Gas > QuickTrip
# - Purchase Behaviors > Q2 Environmentally Concerned Shoppers
# - OnAudience > Interest > Business
# - US  > Green Consumer Audience
# - Media and Entertainment > Sports and Recreational Activities > Interest (Affinity)
# - OnAudience
# - Media and Entertainment > Audio and Video Streaming > Streaming Audio
# - US  > Rural Improvement Fanatic
# - Media and Entertainment > Music
# - OnAudience > Interest > Technology
# - US > Interest Propensities > Social > Premium User Generated Content
# - Telecommunications (Telco) > Subscribers
# - Mobile - US > Device Ownership > Smartphones > Huawei
# - US > Composite Segment > Women Born to Shop
# - Real Estate > Rent Amount > Sensible  Rentals ($1000-$3000)
# - US > AUTO > Decision Maker for Auto Purchase > I shared equally in the decision
# - OnAudience > Interest > Life Stage
# - Mobile - US > Device Ownership > Smartphones > ZTE
# - Transactional > Q2 Graduation Gift Shoppers
# - Media and Entertainment > Consumer Entertainment Technology
# - US Interest > Cooking > General
# - US Financial > Estimated Disposable Income > $0 - $99,999
# - Online Behavior > United States > News > Technology News
# - Online Behavior > United States > News > Business News
# - US > Premium Entertainment and Pastimes > Premium Magazine Enthusiasts
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > iPhone X
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > iPhone 11
# - Real Estate > Sale Activity > Just Sold
# - US Interest > Consumer Electronics
# - US > Interest Propensities > Insurance > Unitedhealth Group
# - US > Interest Propensities > Insurance > Aetna Group
# - OnAudience > Interest > News > Local News
# - US > Response Performance > Direct Marketing Purchasers
# - OnAudience > Interest > News > National News
# - Media Source
# - US > Sociodemographic > P$YCLE Premier Lifestage > M3 Upscale Empty Nests
# - OnAudience > Intent > Education
# - Mobile - US > Sports > UFC Fans
# - Lotame > Technology > Mobile Phones
# - Mobile - US > Device Ownership > Smartphones > Vivo
# - Lotame > Technology > Electronics & Gadgets
# - OnAudience > Intent > Toys & Games
# - Lotame > Technology
# - Lotame > Offline CPG Purchasers > Product Segment
# - Transactional > Q3 Home Entertainers
# - US Financial > Likely In Market Timing > Not At All Likely to Purchase > Second House/Residence In The Next Year (Financial)
# - Mobile - US > Device Ownership > Tablets > yes
# - US > Interest Propensities > Celebrities > Celebrity Fan Gossip
# - US > Interest Propensities > Insurance > Humana
# - Media and Entertainment > Gaming > In-Market
# - Media and Entertainment > Events and Attractions
# - US > Sociodemographic > P$YCLE Premier Lifestage > Y3 Fiscal Fledglings
# - OnAudience > Interest > News & Magazines
# - Lotame > Social Media
# - US > Financially in Charge > Performance Score: Top 25%
# - Media and Entertainment > News and Current Events
# - OnAudience > Interest > Shopping
# - Media and Entertainment > News and Current Events > Online News Websites
# - Tech Enthusiasts
# - US Interest > Computers
# - Media and Entertainment > Audio and Video Streaming > Streaming Video > Interest (Affinity)
# - OnAudience > Interest > Science > Weather
# - Online Behavior > United States > The Changing Consumer > Trending TV Shows
# - OnAudience > Interest > News
# - Transactional > Q3 Casual Dining Restaurant Goers
# - Mobile - US > Device Ownership > Smartphones > iOS (Apple) > yes
# - OnAudience > Interest > Education
# - OnAudience > Intent > Software
# - OnAudience > Intent > Baby & Toddler > Baby Toys
# - Media and Entertainment > Television (TV)
# - Online Behavior > United States > News > Local News
# - Travel and Tourism > In-Market
# - Telecommunications and Mobile Tech > Mobile Devices and Connected Technology
# - US > Sociodemographic > PRIZM Premier Social > C2 City Centers
# - OnAudience > Intent > Electronics > Video Game Consoles
# - Lotame > Style, Fashion & Clothing
# - Purchase-Based
# - OnAudience > Interest > Social life
# - US  > Price-Driven Traditionalist Audience
# - US > Sociodemographic > ConneXions Lifestage > Y2 Emerging Techies
# - US Financial > Likely In Market Timing > Not At All Likely to Purchase > First Home/Residence In The Next Year (Financial)
# - Transactional > Q3 Gardening Shoppers
# - OnAudience > Intent
# - OnAudience > Interest > Pets
# - OnAudience > Interest > Technology & Computing > Email
# - Media and Entertainment > Connected TV and Over-the-Top (CTV and OTT)
# - OnAudience > Interest > Society
# - Mobile - US > Automotive > Repair & Oil Change > Intend
# - Restaurants
# - OnAudience > Interest
# - Media Source > LBDigital > Open For Business B2B
# - OnAudience > Intent > Baby & Toddler
# - US Buying Channel Preference > Online
# - US  > Made In America Audience
# - Purchase Behaviors > Q2 Spring Cleaners
# - US > Sociodemographic > PRIZM Premier Lifestage > F2 Young Accumulators
# - Online Behavior > United States > The Changing Consumer > Pet Adoption
# - Media and Entertainment
# - Retail
# - US > Financially in Charge > Performance Score: Top 50%
# - US > Interest Propensities > Insurance > Lincoln Heritage
# - US Mail Order Buyer
# - OnAudience > Interest > News > International News
# - US Financial > Likely Attitude and Behavior > Completely Disagree > When I Find A Financial Product/Service I Like I Typically Recommend It To People I Know (Financial)
# - US Financial > Method of Payment > Other
# - US  > Quality-First Shopper Audience
# - US Demographic > Preferred Language > Non-Hispanic
# - Online Behavior > United States > News > Weather
# - Media and Entertainment > Television (TV) > Viewership
# - US > Interest Propensities > Activities and Interests > Ecommerce
# - OnAudience > Interest > Technology & Computing
# - Media and Entertainment > Audio and Video Streaming > Streaming Video
# - US > AUTO > Decision Maker for Auto Purchase > I was the sole decision-maker
# - Media and Entertainment > Audio and Video Streaming > Streaming Video > Interest (Affinity) > Streaming Services
# - US > Interest Propensities > Insurance > Transamerica
# - Media & Entertainment
# - Travel and Tourism > Interest (Affinity)
# - US Technology > Social Media > Likely Behavior > Heavy Facebook User
# - Transactional > Q3 Fashion Shoppers
# C:\Users\ek102\.conda\envs\audience-segmentation\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.cluster import KMeans
from collections import Counter
import pandas as pd
from transformers import pipeline

# Initialize Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Define noise tokens
noise_tokens = [
    'United States', 'US', 'Online Behavior', 'Interest',
    'Propensity Models', 'Intent', 'validated', 'Reach', 'OnAudience',
    'ConneXions', 'Brands', 'The Changing Consumer', 'Lotame',
    'Mobile - US', 'Brand Propensities', 'Interest Propensities'
]

# Preprocess tokens by splitting and removing noise tokens
df['tokens'] = df['Audience Segment'].apply(lambda x: [token.strip() for token in x.split('>')])
df['tokens'] = df['tokens'].apply(lambda tokens: [token for token in tokens if token not in noise_tokens])

# Function to get weighted embedding
def get_weighted_embedding(tokens):
    n = len(tokens)
    weighted_embeddings = []

    # Check if there are tokens left after filtering
    if n == 0:
        return np.zeros(model.get_sentence_embedding_dimension())

    for i, token in enumerate(tokens):
        embedding = model.encode(token)
        weight = (i + 1) / n  # Weight inversely proportional to position (closer to leaf = higher weight)
        weighted_embeddings.append(embedding * weight)

    final_embedding = np.sum(weighted_embeddings, axis=0)
    return final_embedding

# Apply the function to the 'tokens' column
df['weighted_embeddings'] = df['tokens'].apply(get_weighted_embedding)

# Convert list of embeddings to a 2D array
X = np.array(df['weighted_embeddings'].tolist())

# Perform clustering
num_clusters = 8  # Adjust based on your data
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Function to generate a representative label from tokens
def generate_cluster_label(cluster_df):
    all_tokens = [token for tokens in cluster_df['tokens'] for token in tokens]
    token_counts = Counter(all_tokens)

    # Select the most common tokens as cluster labels
    common_tokens = token_counts.most_common(3)  # Top 3 tokens
    if common_tokens:
        # Join the top tokens to create a representative label
        return ", ".join(token for token, count in common_tokens)
    return "Other"

# Assign cluster labels using the derived tokens
df['cluster_label'] = df.groupby('cluster').apply(generate_cluster_label).reset_index(drop=True)

# Display results by cluster with labels
for cluster_num in sorted(df['cluster'].unique()):
    print(f"Cluster {cluster_num + 1}: ({df[df['cluster'] == cluster_num]['cluster_label'].iloc[0]})")
    cluster_items = df[df['cluster'] == cluster_num]['tokens']
    for item in cluster_items:
        print(f"- {item}")
    print()
# Out:
# Cluster 1: (Media and Entertainment, Arts and Entertainment, Hobbies and Interest)
# - ['Finance', 'Financial Planning and Management', 'Retirement and Pension']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Purchasing Utilities']
# - ['US Financial', 'Likely Credit Card', 'Card in Own Name', 'Any major Credit/Debit Card (Financial)']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Financial Services']
# - ['Activities and Interests', 'Financial Aid']
# - ['Finance', 'Insurance', 'Home Insurance']
# - ['Finance', 'Investing', 'Derivatives']
# - ['B2B', 'Purchase DM', 'Technology Services, Hardware and', 'or Software', 'I have no input into the final decision']
# - ['US Financial', 'Estimated Discretionary Spending (Financial)', 'Greater than $2,499']
# - ['Sociodemographic', 'Estimated Current Home Value', '$160,000-$199,999']
# - ['Personal Finance', 'Estate Planning']
# - ['US Financial', 'Likely Attitude and Behavior', 'Bank Selection', 'Customer Service Very Important (Financial)']
# - ['Real Estate', 'Monthly Mortgage Payment', '$800-$999']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Company Liability or Insurance']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Employee Benefits']
# - ['Business', 'Economy']
# - ['Finance', 'Financial Planning and Management', 'Asset and Portfolio Management']
# - ['Finance', 'Banking', 'ATMs and Branch Locations']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Advertising Services']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Accounting or Tax Services']
# - ['Finance', 'Insurance', 'Life Insurance']
# - ['Real Estate', 'Rent Amount', 'Sensible  Rentals ($1000-$3000)']
# - ['Finance', 'Credit and Lending', 'Loans']
# - ['Finance', 'Banking', 'Money Transfer and Wire Services']
# - ['Finance', 'Investing', 'Stocks and Bonds']
# - ['Financial Intent', 'Loans and Credit']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Office Supplies or Equipment']
# - ['US Financial', 'Estimated Discretionary Spending', 'Greater than $2,500']
# - ['Personal Finance']
# - ['US Financial', 'Credit Card Type', 'Credit Card Holder - Unknown Type']
# - ['US Financial', 'Estimated Disposable Income', '$0 - $99,999']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Computer Hardware']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Marketing or Market Research']
# - ['Finance', 'Insurance', 'Insurance']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'HR or Personnel Services']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Sales']
# - ['Finance', 'Financial Planning and Management', 'Inheritance and Estate Planning']
# - ['Finance', 'Accounting and Auditing', 'Bookkeeping']
# - ['Finance', 'Credit', 'Debit Card', 'Major Credit Card User']
# - ['Real Estate', 'Mortgage Amount', '$120,000-$159,999']
# - ['Finance', 'Grants, Scholarships and Financial Aid', 'Study Grants and Scholarships']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Computer Software']
# - ['Finance', 'Financial Planning and Management', 'Financial Planning and Management']
# - ['US Financial', 'Likely In Market Timing', 'Not At All Likely to Purchase', 'Second House/Residence In The Next Year (Financial)']
# - ['Finance', 'Banking', 'Banking']
# - ['Finance', 'Credit and Lending', 'Credit and Lending']
# - ['Finance', 'Investing', 'Investing']
# - ['US Financial', 'Likely Bank Account and Services', 'Saving Account', 'Personal or Join (Financial)']
# - ['Financial Intent', 'Banking']
# - ['Finance', 'Insurance', 'Health Insurance']
# - ['Finance', 'Investing', 'Commodities and Futures Trading']
# - ['Finance', 'Investing', 'Brokerages and Day Trading']
# - ['Demographics', 'Finance', 'Rent Value', 'Highest Rent Value']
# - ['Finance', 'Credit and Lending', 'Credit Cards']
# - ['Financial Services', 'Digital Payments', 'Chase Pay']
# - ['Demographics', 'Finance', 'Rent Value', 'Lowest Rent Value']
# - ['Finance', 'Accounting and Auditing', 'Tax Preparation and Planning']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Internet Services']
# - ['B2B', 'Purchase DM', 'Technology Services, Hardware and', 'or Software', 'I am the sole decision maker']
# - ['Finance', 'Credit', 'Debit Card', 'Store Credit Card User']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Office Services or Moving']
# - ['Personal Finance', 'Stocks']
# - ['Finance', 'Grants, Scholarships and Financial Aid', 'Government Grants']
# - ['US Financial', 'Likely In Market Timing', 'Not At All Likely to Purchase', 'First Home/Residence In The Next Year (Financial)']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Security Services']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Television providers', 'services']
# - ['B2B', 'Purchase DM', 'Technology Services, Hardware and', 'or Software', 'I make the final decision with input from staff', 'management']
# - ['Finance', 'Banking', 'Debit and Checking Services']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Print, Copy or Photo Services']
# - ['Finance', 'Banking', 'Savings Accounts']
# - ['Media Source', 'LBDigital', 'Open For Business B2B']
# - ['Finance', 'Insurance', 'Travel Insurance']
# - ['US Financial', 'Likely Attitude and Behavior', 'Completely Disagree', 'When I Find A Financial Product/Service I Like I Typically Recommend It To People I Know (Financial)']
# - ['US Financial', 'Method of Payment', 'Other']
# - ['Finance', 'Accounting and Auditing', 'Accounting and Auditing']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Purchasing Vehicles or Automobile Services']
# - ['Sociodemographic', 'Household Income', '$50,000-$74,999']
# - ['B2B', 'B2B Decision Maker Responsibilities', 'Real Estate Services']
#
# Cluster 2: (nan)
# - ['TV and Movies', 'Sports TV']
# - ['Electronics', 'Video', 'Televisions']
# - ['Arts and Entertainment', 'Events and Listings', 'Bars, Clubs and Nightlife']
# - ['Activities and Interests', 'Local News']
# - ['Home and Garden Interests', 'Cooking', 'Food Enthusiasts']
# - ['Music', 'Country']
# - ['Games', 'Computer and Video Games']
# - ['Hobbies and Interest', 'Food and Drinks', 'Eats at Fast Food Restaurants']
# - ['News', 'Sports News']
# - ['Hobbies and Interest', 'Food and Drinks', 'Wine Lovers']
# - ['Media and Entertainment', 'Gaming', 'Interest (Affinity)', 'Video Games']
# - ['Games', 'Card Games']
# - ['Hobbies and Interest', 'Photography']
# - ['Activities and Interests', 'International News']
# - ['News', 'Newspapers']
# - ['Media and Entertainment', 'Connected TV and Over-the-Top (CTV and OTT)', 'Streaming Television and Film Viewership', 'OTT Movie Viewers', 'Genre', 'Crime Movie Streamers']
# - ['Hobbies and Interest', 'Food and Drinks', 'High-end Spirit Drinkers']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)']
# - ['Arts and Entertainment', 'Music and Audio']
# - ['Media and Entertainment', 'Audio and Video Streaming', 'Streaming Audio']
# - ['Food and Drink', 'Restaurants', 'Dining Guides']
# - ['Media and Entertainment', 'Music']
# - ['Food', 'Restaurant', 'Style', 'Desserts']
# - ['Arts and Entertainment', 'Events and Listings', 'Film Festivals']
# - ['Arts & Entertainment', 'Celebrity Fan', 'Gossip']
# - ['Media and Entertainment', 'Consumer Entertainment Technology']
# - ['News', 'Technology News']
# - ['News', 'Business News']
# - ['Premium Entertainment and Pastimes', 'Premium Magazine Enthusiasts']
# - ['Games', 'Family-Oriented Games and Activities']
# - ['Games', 'Educational Games']
# - ['Food and Drink', 'Beverages', 'Bottled Water']
# - ['Arts & Entertainment', 'Television']
# - ['Arts and Entertainment', 'Comics and Animation']
# - ['Food and Drink', 'Beverages', 'Coffee and Tea']
# - ['News', 'Local News']
# - ['Arts & Entertainment', 'Music Lovers']
# - ['Arts and Entertainment', 'Movies']
# - ['Games']
# - ['Hobbies and Leisure', 'Contests, Awards and Prizes']
# - ['News', 'National News']
# - ['Media Source']
# - ['Arts and Entertainment', 'Celebrities and Entertainment News']
# - ['Arts & Entertainment', 'Fine Art']
# - ['Food and Drink', 'Beverages', 'Soft Drinks']
# - ['Food and Drink', 'Restaurants', 'Fast Food']
# - ['Arts and Entertainment', 'Events and Listings', 'Food and Beverage Events']
# - ['Hobbies and Interest', 'Music', 'Streaming']
# - ['Home Entertaining']
# - ['Food and Drink', 'Restaurants']
# - ['Shopping', 'Entertainment']
# - ['Hobbies and Leisure', 'Special Occasions', 'Party Planning']
# - ['Hobbies and Interest', 'Music', 'Listens to Pop Music']
# - ['Hobbies and Interest', 'Music', 'Listens to Country Music']
# - ['Hobbies and Leisure', 'Outdoors', 'Fishing']
# - ['Celebrities', 'Celebrity Fan Gossip']
# - ['Media and Entertainment', 'Gaming', 'In-Market']
# - ['Media and Entertainment', 'Events and Attractions']
# - ['Services', 'Arts and Entertainment']
# - ['Arts and Entertainment', 'TV and Video']
# - ['News & Magazines']
# - ['Arts and Entertainment', 'Events and Listings', 'Live Sporting Events']
# - ['Arts and Entertainment', 'Arts and Entertainment']
# - ['Media and Entertainment', 'News and Current Events']
# - ['Activities and Interests', 'National News']
# - ['TV and Movies', 'Reality', 'Game Shows']
# - ['Media and Entertainment', 'News and Current Events', 'Online News Websites']
# - ['Media and Entertainment', 'Audio and Video Streaming', 'Streaming Video', 'Interest (Affinity)']
# - ['Trending TV Shows']
# - ['News']
# - ['Hobbies and Interest', 'Cultural Arts']
# - ['Hobbies and Interest', 'Food and Drinks', 'Eats at Family Restaurants']
# - ['Media and Entertainment', 'Television (TV)']
# - ['News', 'Local News']
# - ['Food and Drink', 'Beverages', 'Juice']
# - ['Food and Drink', 'American Cuisine']
# - ['TV and Movies', 'Network TV']
# - ['Arts & Entertainment', 'Movies']
# - ['Arts & Entertainment']
# - ['Multibuyer Behaviors', 'Entertainment', 'Pastimes Multibuyer']
# - ['Music', 'Classic Rock']
# - ['Media and Entertainment', 'Television (TV)', 'Viewership', 'TV Genres', 'Drama']
# - ['Streaming Services']
# - ['Media and Entertainment', 'Connected TV and Over-the-Top (CTV and OTT)']
# - ['News', 'Politics']
# - ['Food and Drink', 'Restaurants', 'Fine Dining']
# - ['Hobbies & Interests', 'Art']
# - ['Arts and Entertainment', 'Events and Listings', 'Concerts and Music Festivals']
# - ['Food & Drink']
# - ['Food and Drink', 'Cooking and Recipes']
# - ['Hobbies and Leisure', 'Clubs and Organizations']
# - ['Hobbies and Leisure', 'Water Activities']
# - ['Media and Entertainment']
# - ['News', 'International News']
# - ['Mobile Audience', 'Lifestyle', 'Arts Enthusiasts']
# - ['Music', 'Hip Hop and Rap']
# - ['Entertainment and Pastimes', 'Entertainment and Pastimes']
# - ['Arts and Entertainment', 'Events and Listings', 'Event Ticket Sales']
# - ['Media and Entertainment', 'Television (TV)', 'Viewership']
# - ['Media and Entertainment', 'Movies', 'Enthusiasts']
# - ['Media and Entertainment', 'Audio and Video Streaming', 'Streaming Video']
# - ['Games', 'Arcade and Coin-Op Games']
# - ['Hobbies and Leisure', 'Special Occasions', 'Holidays and Seasonal Events']
# - ['Hobbies and Interest', 'Books', 'E-Book Reader']
# - ['Media and Entertainment', 'Audio and Video Streaming', 'Streaming Video', 'Interest (Affinity)', 'Streaming Services']
# - ['TV and Movies', 'Drama']
# - ['Media & Entertainment']
# - ['Technology & Computing', 'Entertainment']
# - ['Hobbies and Interest', 'Food and Drinks', 'Coffee Connoisseurs']
# - ['Food and Drink', 'Beverages', 'Beer']
# - ['Arts and Entertainment', 'Events and Listings', 'Expos and Conventions']
#
# Cluster 3: (Validated Demographic, Gender and Age Combined, Age)
# - ['Auto Buyers', 'Car Make', 'Audi Q']
# - ['Autos and Vehicles', 'Jeep']
# - ['Autos and Vehicles', 'Mercedes-Benz']
# - ['Auto Buyers', 'Car Make', 'Volkswagen']
# - ['Autos and Vehicles', 'Dodge']
# - ['Autos and Vehicles', 'Ferrari']
# - ['AUTO', 'Primary Vehicle', 'New or Used', 'Pre-owned']
# - ['Autos and Vehicles', 'Rolls-Royce']
# - ['Auto Buyers', 'Car Make', 'Nissan']
# - ['Autos and Vehicles', 'Mazda']
# - ['Autos and Vehicles', 'Volvo']
# - ['Auto Buyers', 'Car Make', 'Toyota']
# - ['Auto Buyers', 'Car Make', 'Hyundai']
# - ['Autos and Vehicles', 'LandRover']
# - ['Auto', 'Vehicle Parts & Accessories']
# - ['Autos and Vehicles', 'Cadillac']
# - ['Auto Buyers', 'Category', 'Motorcycle']
# - ['Autos and Vehicles', 'Boats and Watercraft']
# - ['Auto Buyers', 'Car Make', 'Opel']
# - ['Auto Buyers', 'Car Make', 'BMW']
# - ['Autos and Vehicles', 'BMW']
# - ['Auto Buyers', 'Car Make', 'Ford']
# - ['Autos and Vehicles', 'Maserati']
# - ['Autos and Vehicles', 'Hybrid and Alternative Vehicles']
# - ['Auto Buyers', 'Car Make', 'Dodge']
# - ['Auto Buyers', 'Type', 'SUV']
# - ['Auto Buyers', 'Car Make', 'Mazda']
# - ['Shopping', 'Auto Parts Stores']
# - ['Autos and Vehicles', 'Ford']
# - ['Autos and Vehicles', 'SEAT']
# - ['Autos and Vehicles', 'Acura']
# - ['Auto Buyers', 'Type', 'Sedan']
# - ['Automotive', 'Vehicle Ownership', 'yes']
# - ['Automotive', 'Tirerack.com Buyer Propensity']
# - ['Autos and Vehicles', 'Honda']
# - ['Autos and Vehicles', 'Volkswagen']
# - ['Autos and Vehicles', 'Jaguar']
# - ['Autos and Vehicles', 'Bugatti']
# - ['Autos and Vehicles', 'Electric and Plug-In Vehicles']
# - ['Auto Buyers', 'Type', 'Truck']
# - ['Autos and Vehicles', 'Porsche']
# - ['Autos and Vehicles', 'Mitsubishi']
# - ['Autos and Vehicles', 'GM-Daewoo']
# - ['Autos and Vehicles', 'Vehicle Shopping', 'Fuel Economy and Gas Prices']
# - ['Auto Buyers', 'Car Make', 'Honda']
# - ['Auto Buyers', 'Car Make', 'Vauxhall']
# - ['AUTO', 'Primary Vehicle', 'Owned or Leased', 'Company Car']
# - ['Autos and Vehicles', 'Vehicle Parts and Accessories']
# - ['Auto Buyers', 'Category', 'Sport Cars']
# - ['Auto Buyers', 'Category', 'Caravan']
# - ['Auto Buyers', 'Car Make', 'Mercedes']
# - ['Autos and Vehicles', 'Isuzu']
# - ['Autos and Vehicles', 'Citroen']
# - ['Automotive', 'Auto Loyalists and Defectors', 'Auto Make Defectors']
# - ['Auto Buyers', 'Car Make', 'Subaru']
# - ['Autos and Vehicles', 'Mini']
# - ['Autos and Vehicles', 'Buick']
# - ['Autos and Vehicles', 'Lexus']
# - ['Autos and Vehicles', 'Pontiac']
# - ['Auto Buyers', 'Category', 'Van']
# - ['Autos and Vehicles', 'Nissan']
# - ['Autos and Vehicles', 'Fiat']
# - ['Autos and Vehicles', 'Peugeot']
# - ['Auto Buyers', 'Car Make', 'Peugeot']
# - ['Automotive', 'Vehicle Ownership', 'Brand', 'BMW']
# - ['Financial Intent', 'Insurance', 'Auto']
# - ['Auto Buyers', 'Car Make', 'Jeep']
# - ['Autos and Vehicles', 'Kia']
# - ['AUTO', 'Auto Car Purchase Next Year', 'Yes']
# - ['Autos and Vehicles', 'Vauxhall-Opel']
# - ['Autos and Vehicles', 'Aston Martin']
# - ['Automotive', 'Ford Credit Buyer Propensity']
#
# Cluster 4: (Finance, B2B, B2B Decision Maker Responsibilities)
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 25 or older']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 18-54']
# - ['Validated Demographic', 'Age', '55-64']
# - ['Demo', 'Age', '55-64']
# - ['Premium Gender', 'Premium Gender', 'Males']
# - ['Validated Demographic', 'Age', '18-64']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 25-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 45-54']
# - ['Validated Demographic', 'Age', '25-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 18-54']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 35-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 65 or older']
# - ['Sociodemographic', 'Age', '45-49']
# - ['Validated Demographic', 'Age', '35-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 25-34']
# - ['Validated Demographic', 'Gender', 'Male']
# - ['Validated Demographic', 'Age', '25 or older']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 18-64']
# - ['Validated Demographic', 'Age', '25-34']
# - ['Validated Demographic', 'Age', '18-54']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 18-64']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 25-64']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 18-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 25-54']
# - ['Validated Demographic', 'Age', '25-64']
# - ['Demo', 'Age', '65+']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 18-34']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 55-64']
# - ['Validated Demographic', 'Gender and Age Combined', 'Females 25-44']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 18-44']
# - ['Validated Demographic', 'Age', '18 or older']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 25-64']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 55-64']
# - ['Validated Demographic', 'Age', '65 or older']
# - ['Validated Demographic', 'Gender and Age Combined', 'Males 25 or older']
# - ['Validated Demographic', 'Age', '25-54']
# - ['US Demographic', 'Age', 'Specialty Age Range', '21+']
# - ['Validated Demographic', 'Gender', 'Female']
#
# Cluster 5: (Beauty and Fitness, Shopping, Device Ownership)
# - ['Beauty and Fitness', 'Fitness', 'Fitness Instruction and Personal Training']
# - ['Quick Service Restaurants']
# - ['Software', 'Video Game Software']
# - ['Media and Entertainment', 'wwe.com Buyer Propensity']
# - ['Beauty and Fitness', 'Face and Body Care', 'Skin and Nail Care']
# - ['Multibuyer Behaviors', 'Paid with Credit Card']
# - ['Response Performance', 'Direct Marketing Responders']
# - ['Telecommunications (Telco)']
# - ['Connected Impulse-Shopper Audience']
# - ['Internet Connection']
# - ['Sporting Goods']
# - ['Shopping', 'Consumer Electronics', 'Computers, Laptops']
# - ['Oil & Gas', 'QuickTrip']
# - ['Shopping', 'Shopping Mall Buyers']
# - ['Purchase Behaviors', 'Q2 Environmentally Concerned Shoppers']
# - ['Green Consumer Audience']
# - ['Direct to Consumer']
# - ['Luxury Home Goods Store Shopper']
# - []
# - ['Rural Improvement Fanatic']
# - ['Gaming Equipment']
# - ['Beauty and Fitness', 'Face and Body Care', 'Unwanted Body and Facial Hair Removal']
# - ['Technology']
# - ['Social', 'Premium User Generated Content']
# - ['Telecommunications (Telco)', 'Subscribers']
# - ['Health', 'Beauty and Cosmetics', 'Bare Escentuals Buyer Propensity']
# - ['Device Ownership', 'Smartphones', 'Huawei']
# - ['Internet and Telecom', 'Email and Messaging']
# - ['Beauty and Fitness', 'Cosmetology and Beauty Professionals']
# - ['Food and Drink', 'Food and Grocery Retailers']
# - ['Shopping', 'Drug Stores', 'CVS']
# - ['Composite Segment', 'Women Born to Shop']
# - ['Online Communities', 'File Sharing and Hosting']
# - ['Food and Drink', 'Food and Grocery Delivery']
# - ['AUTO', 'Decision Maker for Auto Purchase', 'I shared equally in the decision']
# - ['Device Ownership', 'Smartphones', 'ZTE']
# - ['Health', 'Beauty and Cosmetics', 'SkinCareRx Buyer Propensity']
# - ['Health', 'Beauty and Cosmetics', 'Mary Kay Buyer Propensity']
# - ['Transactional', 'Q2 Graduation Gift Shoppers']
# - ['Offline CPG Purchasers', 'Product Segment', 'Home Supplies']
# - ['Shopping', 'Consumer Electronics', 'Video Game Consoles']
# - ['Travel', 'Booking.com Buyer Propensity']
# - ['Beauty and Fitness', 'Fitness', 'Yoga and Pilates']
# - ['Beauty and Fitness', 'Body Art']
# - ['Active Facebook Users']
# - ['Media and Entertainment', 'Regal Cinemas Buyer Propensity']
# - ['Device Ownership', 'Smartphones', 'iOS (Apple)', 'iPhone X']
# - ['Device Ownership', 'Smartphones', 'iOS (Apple)', 'iPhone 11']
# - ['Lifestyle', 'Loyalty Programs', 'Loyalty Card User']
# - ['Shopping', 'Consumer Electronics', 'Tablets']
# - ['Online Communities', 'Social Networks']
# - ['Online Communities', 'Photo and Video Sharing']
# - ['Internet and Telecom', 'Mobile and Wireless']
# - ['Beauty and Fitness', 'Fashion and Style', 'Fashion Modeling']
# - ['Real Estate', 'Sale Activity', 'Just Sold']
# - ['US Interest', 'Consumer Electronics']
# - ['Shopping', 'Consumer Electronics', 'Cameras and Photography Equip']
# - ['Response Performance', 'Direct Marketing Purchasers']
# - ['B2B Work from Home']
# - ['Apparel', 'JCPenney Buyer Propensity']
# - ['Technology & Computing', 'Internet Technology']
# - ['Technology', 'Mobile Phones']
# - ['Online Retailers']
# - ['Home and Household Goods', 'Pottery Barn Kids Buyer Propensity']
# - ['Shopping', 'Drug Stores']
# - ['Device Ownership', 'Smartphones', 'Vivo']
# - ['Style, Fashion & Clothing', "Women's Clothing Shoppers"]
# - ['Shopping', 'Office Supplies']
# - ['Technology', 'Electronics & Gadgets']
# - ['Toys & Games']
# - ['Style, Fashion & Clothing', "Children's Clothing Shoppers"]
# - ['Technology']
# - ['Delivery Services and Quick Service Restaurants']
# - ['Health', 'Beauty and Cosmetics', 'ULTA Buyer Propensity']
# - ['Home and Garden Interests', 'House and Garden Merchandise Buyers']
# - ['Offline CPG Purchasers', 'Product Segment']
# - ['Apparel', 'Bare Necessities Buyer Propensity']
# - ['Media and Entertainment', 'Sony Network Entertainment International Buyer Propensity']
# - ['Beauty and Fitness', 'Fitness']
# - ['Beauty and Fitness', 'Fashion and Style', 'Fashion Designers and Collections']
# - ['Beauty and Fitness', 'Weight Loss']
# - ['Media and Entertainment', 'Steam Community Buyer Propensity']
# - ['Style, Fashion & Clothing', 'Clothing Shoppers']
# - ['Transactional', 'Q3 Home Entertainers']
# - ['Personal Budgeting']
# - ['Device Ownership', 'Tablets', 'yes']
# - ['Telecom and Service Providers', 'Page Plus Cellular Buyer Propensity']
# - ['Beauty and Fitness', 'Fashion and Style']
# - ['Shopping', 'Wireless Providers']
# - ['Activities and Interests', 'B2B Job Search']
# - ['Beauty and Fitness', 'Hair Care']
# - ['Shopping', 'Consumer Electronics', 'Televisions/TVs']
# - ['Beauty and Fitness', 'Spas and Beauty Services', 'Massage Therapy']
# - ['Electronics', 'RadioShack Buyer Propensity']
# - ['Social Media']
# - ['Financially in Charge', 'Performance Score: Top 25%']
# - ['Kids Products', 'Disney Buyer Propensity']
# - ['Shopping']
# - ['Luxury Store Shoppers']
# - ['Tech Enthusiasts']
# - ['US Interest', 'Computers']
# - ['Health', 'Beauty and Cosmetics', 'Beachbody Buyer Propensity']
# - ['Shopping', 'Fashion']
# - ['Apparel', 'TOMS Buyer Propensity']
# - ['Transactional', 'Q3 Casual Dining Restaurant Goers']
# - ['Big Box Dollar Tree Buyer Propensity']
# - ['Food and Drug', 'Postmates Buyer Propensity']
# - ['Online Communities', 'Online Goodies']
# - ['Device Ownership', 'Smartphones', 'iOS (Apple)', 'yes']
# - ['Software']
# - ['Baby & Toddler', 'Baby Toys']
# - ['CPG']
# - ['Internet and Telecom', 'Web Apps and Online Tools']
# - ['Internet and Telecom', 'Web Services']
# - ['Apparel', 'Shoebuy.com Buyer Propensity']
# - ['Travel and Tourism', 'In-Market']
# - ['Telecommunications and Mobile Tech', 'Mobile Devices and Connected Technology']
# - ['Electronics', 'Video Game Consoles']
# - ['Beauty and Fitness', 'Fitness', 'Gyms and Health Clubs']
# - ['Style, Fashion & Clothing']
# - ['Online Shoppers', 'Online Shoppers']
# - ['Young Adult Clothing Shoppers']
# - ['Purchase-Based']
# - ['Online', 'Electronics and Gadgets']
# - ['Price-Driven Traditionalist Audience']
# - ['Online Communities', 'Blogging Resources and Services']
# - ['Electronics', 'Crutchfield Buyer Propensity']
# - ['Transactional', 'Q3 Gardening Shoppers']
# - ['Telehealth']
# - []
# - ['Technology & Computing', 'Email']
# - ['DIY']
# - ['Apparel', 'Lady Foot Locker Buyer Propensity']
# - ['Shopping', 'Luxurious Brands']
# - ['Restaurants']
# - []
# - ['Baby & Toddler']
# - ['Beauty and Fitness', 'Fitness', 'Fitness Equipment and Accessories']
# - ['US Buying Channel Preference', 'Online']
# - ['Made In America Audience']
# - ['Shopping', 'Drug Stores', 'Walgreens']
# - ['Purchase Behaviors', 'Q2 Spring Cleaners']
# - ['Online Communities', 'Dating and Personals']
# - ['Internet and Telecom', 'Search Engines']
# - ['Internet and Telecom', 'Web Portals']
# - ['Shopping', 'CPG', 'Cosmetics']
# - ['Pet Adoption']
# - ['Retail']
# - ['Financially in Charge', 'Performance Score: Top 50%']
# - ['US Mail Order Buyer']
# - ['Big Box Dollar General Buyer Propensity']
# - ['Purchase-Based', 'Categories', 'Office Supplies Buyers']
# - ['Home Learning']
# - ['Quality-First Shopper Audience']
# - ['Activities and Interests', 'Ecommerce']
# - ['Technology & Computing']
# - ['Beauty and Fitness', 'Spas and Beauty Services']
# - ['Virtual Events']
# - ['Beauty and Fitness', 'Beauty Pageants']
# - ['AUTO', 'Decision Maker for Auto Purchase', 'I was the sole decision-maker']
# - ['Apparel', "The Men's Wearhouse Buyer Propensity"]
# - ['Restaurants and Dining', 'Seamless Buyer Propensity']
# - ['Big Box Retail']
# - ['Travel and Tourism', 'Interest (Affinity)']
# - ['Media and Entertainment', 'pokerstars.net Buyer Propensity']
# - ['Beauty and Fitness', 'Face and Body Care', 'Make-Up and Cosmetics']
# - ['Transactional', 'Q3 Fashion Shoppers']
# - ['Style, Fashion & Clothing', "Men's Clothing Shoppers"]
#
# Cluster 6: (Autos and Vehicles, Auto Buyers, Car Make)
# - ['Hobbies and Leisure', 'Outdoors', 'Equestrian']
# - ['Sports', 'Sports League', 'NFL']
# - ['Sports', 'Team Sports', 'Basketball']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Team Sports', 'Baseball', 'Major League Baseball (MLB)']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Olympics', 'Summer Olympics']
# - ['Sports', 'Sports League', 'MLB']
# - ['Sports', 'Sports League', 'NBA']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Motorsports']
# - ['Sports', 'Team Sports', 'Volleyball']
# - ['Sports', 'Sporting Goods']
# - ['Sports', 'Winter Sports', 'Skiing and Snowboarding']
# - ['Sports', 'Fantasy Sports']
# - ['Sports', 'Individual Sports', 'Running and Walking']
# - ['Hobbies and Interest', 'Sports', 'Avid Runners']
# - ['Sporting Goods', 'Team Sports']
# - ['Sports', 'Sports League', 'Premier League']
# - ['Sports', 'Sports League', 'NHL']
# - ['Sports', 'Water Sports', 'Surfing']
# - ['Hobbies and Interest', 'Sports', 'Fitness Enthusiasts']
# - ['Sports']
# - ['Shopping', 'Sports and Outdoors']
# - ['Sports', 'Motor Sports']
# - ['Hobbies and Interest', 'Sports', 'Plays Soccer']
# - ['Sports', 'Water Sports', 'Boating']
# - ['Sports', 'UFC Fans']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Individual Sports', 'Tennis and Racquet Sports']
# - ['Hobbies and Interest', 'Sports', 'NBA Enthusiast']
# - ['Sports', 'Individual Sports', 'Track and Field']
# - ['Sports', 'Individual Sports', 'Bowling']
# - ['Sports', 'Team Sports', 'Rugby']
# - ['Sports', 'Winter Sports', 'Ice Skating']
# - ['Hobbies and Interest', 'Sports', 'PGA Tour Enthusiast']
# - ['Hobbies and Interest', 'Sports', 'NASCAR Enthusiast']
# - ['Sports', 'Individual Sports', 'Skate Sports']
# - ['Hobbies and Interest', 'Sports', 'NFL Enthusiast']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Team Sports', 'Soccer (Football)']
# - ['Sports', 'Team Sports', 'American Football']
# - ['Sports', 'Individual Sports', 'Cycling']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Team Sports', 'Football (American)']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Olympics']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Team Sports', 'Baseball']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Combat Sports']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Olympics', 'Winter Olympics']
# - ['Hobbies and Interest', 'Sports', 'Hunting Enthusiasts']
# - ['Sports', 'Individual Sports', 'Golf']
# - ['Hobbies and Interest', 'Sports', 'NHL Enthusiast']
# - ['Hobbies and Interest', 'Sports', 'Fishing']
# - ['Sports', 'Team Sports', 'Baseball']
# - ['Hobbies and Interest', 'Sports', 'Plays Tennis']
# - ['Hobbies and Interest', 'Sports', 'Canoeing', 'Kayaking']
# - ['Sports', 'College Sports']
# - ['Hobbies and Interest', 'Sports', 'Boating']
# - ['Sports', 'Extreme Sports']
# - ['Sports', 'Basketball', 'NCAA College Basketball']
# - ['Media and Entertainment', 'Sports and Recreational Activities', 'Interest (Affinity)', 'Individual Sports']
# - ['Sports', 'Motor Sports', 'NASCAR']
#
# Cluster 7: (nan)
# - ['Real Estate', 'Occupancy', 'Owner Occupied']
# - ['People and Society', 'Millennials']
# - ['Sociodemographic', 'Dwelling Type', 'Multi-family Dwelling Unit']
# - ['B2B', 'Occupation', 'Musician']
# - ['Auto Buyers', 'Type', 'Luxury']
# - ['Demographic', 'Family', 'Female Head of Household']
# - ['Shopping', 'Brand', 'Old Navy']
# - ['Animals & Pet']
# - ['Sociodemographic', 'Dwelling Size', '1 Unit']
# - ['B2B', 'Occupation', 'MechanicalEngineer']
# - ['Insurance', 'MassMutual']
# - ['Law and Government', 'Public Safety']
# - ['Jobs and Education', 'Education']
# - ['Careers']
# - ['Science', 'Weather Forecast']
# - ['Life Event', 'Bride']
# - ['Life Event', 'Engagement']
# - ['Food', 'Restaurant', 'Brand', 'Outback Steakhouse']
# - ['Household Consumer Expenditures', 'Home Office']
# - ['Law and Government', 'Military']
# - ['People and Society', 'Family and Relationships', 'Parents']
# - ['Business']
# - ['Household Consumer Expenditures', 'Lawn and Garden']
# - ['US Interest', 'Home', 'Home Improvement', 'Home Improvement Grouping']
# - ['Real Estate', 'Apartments and Residential Rentals']
# - ['Lifestyle', 'Charities', 'Contributes to Charities']
# - ['Household Consumer Expenditures', 'Kitchen']
# - ['B2B', 'Occupation', 'OfficeManager']
# - ['Shopping', 'CPG', 'Grocery']
# - ['Home and Garden', 'Homemaking and Interior Decor']
# - ['Sociodemographic', 'P$YCLE Premier Lifestage', 'M2 Wealthy Achievers']
# - ['AUTO', 'Primary Vehicle', 'New or Used', 'New']
# - ['Life Event', 'New Parent']
# - ['Real Estate', 'Homeowner']
# - ['B2B', 'Occupation', 'Student']
# - ['Hobbies and Interest', 'Pets', 'Cat Owners']
# - ['Life Stage']
# - ['Activities and Interests', 'Fashion']
# - ['Travel', 'Car Rentals', 'Hertz']
# - ['Food', 'Restaurant', 'Brand', 'Five Guys']
# - ['Insurance', 'Northwestern Mutual']
# - ['B2B', 'Occupation', 'SystemsAnalyst']
# - ['Demographics', 'Education', 'Lowest Education Achievement']
# - ['Food', 'Restaurant', 'Brand', 'Buffalo Wild Wings']
# - ['US Interest', 'Cooking', 'General']
# - ['Home and Garden', 'Home Improvement']
# - ['Sociodemographic', 'ConneXions Lifestage', 'F1 Early Adopting Elite']
# - ['Insurance', 'Unitedhealth Group']
# - ['Insurance', 'Aetna Group']
# - ['Sociodemographic', 'Homeowner Status', 'Renter']
# - ['Sociodemographic', 'PRIZM Premier Social', 'T2 Country Comfort']
# - ['US Home', 'Dwelling Type', 'Single-Family']
# - ['Autos and Vehicles', 'Saab']
# - ['Sociodemographic', 'ConneXions Lifestage', 'M3 Offline Seniors']
# - ['People and Society', 'Seniors and Retirement']
# - ['Sociodemographic', 'P$YCLE Premier Lifestage', 'M3 Upscale Empty Nests']
# - ['US Demographic', 'Preferred Language', 'Individual', 'Non-Hispanic']
# - ['Education']
# - ['Autos and Vehicles', 'Maybach']
# - ['Home Cooking']
# - ['B2B', 'Occupation', 'Teacher']
# - ['Services', 'Photography']
# - ['Data For Good', 'Current Affairs - Social Justice']
# - ['Sociodemographic', 'ConneXions Lifestage', 'M4 Elderly Traditionalists']
# - ['Demographic', 'Family', 'Households with 3 Adults']
# - ['Food', 'Restaurant', 'Brand', 'Moes Southwest Grill']
# - ['Health and Wellbeing', 'Health and Wellbeing']
# - ['B2B', 'Occupation', 'ElectricalEngineer']
# - ['Household Consumer Expenditures', 'Furniture']
# - ['Insurance', 'Humana']
# - ['Life Event', 'College Graduation']
# - ['Happy at Home']
# - ['Shopping', 'Home and Garden']
# - ['Sociodemographic', 'P$YCLE Premier Lifestage', 'Y3 Fiscal Fledglings']
# - ['Activities and Interests', 'College Life']
# - ['Hobbies and Interest', 'Pets', 'Pet Enthusiast']
# - ['B2B', 'Occupation', 'SupplyChainManager']
# - ['People and Society', 'Family and Relationships', 'Moms']
# - ['Beauty and Fitness', 'Fitness', 'Home Exercise']
# - ['Hobbies and Leisure', 'Crafts']
# - ['Life Event', 'Wedding Planning']
# - ['Home and Garden', 'Home Appliances']
# - ['Home and Garden', 'Home Furnishings']
# - ['Insurance', 'New York Life']
# - ['Science', 'Weather']
# - ['Natural Disasters']
# - ['Online', 'Home Office']
# - ['Food', 'Restaurant', 'Brand', 'Chilis']
# - ['Beauty and Fitness', 'Fitness', 'Bodybuilding']
# - ['Jobs and Education', 'Jobs']
# - ['Education']
# - ['Home and Garden', 'Kitchen and Dining']
# - ['B2B', 'Occupation', 'ComputerProgrammer']
# - ['Lifestyle', 'Healthy Living']
# - ['Sociodemographic', 'P$YCLE Premier Lifestage', 'F4 Working-Class USA']
# - ['US Home', 'Property Type', 'Single']
# - ['US Health and Fitness', 'Exercise', 'Health']
# - ['Sociodemographic', 'PRIZM Premier Social', 'C2 City Centers']
# - ['Social life']
# - ['Sociodemographic', 'ConneXions Lifestage', 'Y2 Emerging Techies']
# - ['Law and Government', 'Government']
# - ['US Financial', 'Likely Credit Card', 'Behavior', 'Used for Personal Purposes']
# - ['Demographic', 'Family', 'Male Head of Household']
# - ['Lifestyle', 'Charities', 'Contributes by Volunteering']
# - ['Pets']
# - ['Home and Garden', 'Bed and Bath']
# - ['B2B', 'Occupation', 'Broker']
# - ['Society']
# - ['Automotive', 'Repair & Oil Change', 'Intend']
# - ['Home Renovation', 'Home Renovators']
# - ['Life Event', 'Job Search']
# - ['Demographic', 'Household Income $50k+']
# - ['Food', 'Restaurant', 'Brand', 'Red Lobster']
# - ['Beauty and Fitness', 'Face and Body Care', 'Hygiene and Toiletries']
# - ['Gamers', 'Online', 'Users']
# - ['Activities and Interests', 'Buying and Selling Homes', 'Real Estate']
# - ['Real Estate', 'Property Type', 'Residential']
# - ['Life Event', 'Home Buying']
# - ['Auto Buyers', 'Type', 'Crossover']
# - ['Food', 'Restaurant', 'Brand', 'Krispy Kreme']
# - ['Home and Garden', 'Yard and Patio']
# - ['Sociodemographic', 'PRIZM Premier Lifestage', 'F2 Young Accumulators']
# - ['Law and Government', 'Legal']
# - ['B2B', 'Occupation', 'Entrepreneur']
# - ['Shopping', 'CPG', 'Home Care']
# - ['Services', 'Restaurants']
# - ['Online', 'Pets']
# - ['Insurance', 'Lincoln Heritage']
# - ['Real Estate', 'Lot Size', 'Cozy Outdoor Living Space (Less than  an Acre)']
# - ['Sociodemographic', 'ConneXions Lifestage', 'F2 Suburban Spenders']
# - ['Auto Buyers', 'New']
# - ['B2B', 'Occupation', 'PropertyManager']
# - ['US Demographic', 'Preferred Language', 'Non-Hispanic']
# - ['News', 'Weather']
# - ['Shopping', 'Home Improvement']
# - ['Life Event', 'University Graduation']
# - ['Life Event', 'College Applications']
# - ['Life Event', 'Movers']
# - ['Services', 'Pets']
# - ['Demographics', 'Education', 'High Education Achievement']
# - ['Insurance', 'Transamerica']
# - ['Demographic', 'Family', 'Households with 2 Adults']
# - ['Shopping', 'Pet Food', 'Dog']
# - ['B2B', 'Occupation', 'Architect']
# - ['Multibuyer Behaviors', 'Club', 'Continuity Buyers']
# - ['US Technology', 'Social Media', 'Likely Behavior', 'Heavy Facebook User']
#
# Cluster 8: (nan)
# - ['Travel', 'Summer Travel']
# - ['Travel', 'Sandals Resorts Buyer Propensity']
# - ['Travel', 'Specialty Travel', 'Adventure Travel']
# - ['Travel', 'Tourist Destinations', 'Zoos-Aquariums-Preserves']
# - ['Travel', 'Choice Hotels Buyer Propensity']
# - ['Travel', 'Hotel Tonight Buyer Propensity']
# - ['Travel', 'Destination', 'International Travelers', 'Frequent Travelers']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Destinations', 'North America']
# - ['Travel', 'Bus and Rail']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Destinations', 'North America']
# - ['Travel', 'Tourist Destinations', 'Regional Parks and Gardens']
# - ['Travel', 'Tourist Destinations', 'Mountain and Ski Resorts']
# - ['Travel', 'Tourist Destinations', 'Beaches and Islands']
# - ['Travel', 'American Airlines Buyer Propensity']
# - ['Travel', 'Travel']
# - ['Travel', 'Accommodation', 'Hotels']
# - ['Travel', 'Car Rental and Taxi Services']
# - ['Travel', 'Cruises']
# - ['Travel', 'Tourist Destinations']
# - ['Hobbies and Leisure', 'Outdoors', 'Hiking and Camping']
# - ['Travel', 'Cruises and Charters']
# - ['Travel', 'International Travel']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Destinations', 'Latin America']
# - ['Travel', 'Air Travel']
# - ['Travel', 'Tourist Destinations', 'Lakes and Rivers']
# - ['Travel', 'Vacation Rentals', 'HomeAway']
# - ['Travel', 'Business Travel']
# - ['Travel', 'Activity', 'Ski Travelers']
# - ['Travel', 'Winter Holiday Travel']
# - ['Travel', 'Air Travel', 'Airport Parking and Transportation']
# - ['Travel', 'Destination', 'International Travelers', 'yes']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Destinations', 'Europe']
# - ['Travel', 'Travel Agencies and Services']
# - ['Travel', 'Specialty Travel', 'Agritourism']
# - ['Travel']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Products', 'Hotels and Lodging']
# - ['Travel', 'Business Travel']
# - ['Travel']
# - ['Travel', 'Travel Agencies and Services', 'Tourist Boards and Visitor Centers']
# - ['Travel', 'High Frequency Travel', 'Foreign Vacationer']
# - ['Travel', 'Flights']
# - ['Travel', 'Hotels and Accommodations']
# - ['Travel', 'Graduation Trip']
# - ['US Travel', 'Likely Business Travel', 'Number of Nights Stayed', '0 Nights']
# - ['Travel', 'Luxury Travel']
# - ['Travel', 'Tourist Destinations', 'Historical Sites and Buildings']
# - ['Travel', 'Carpooling and Vehicle Sharing']
# - ['Travel', 'MGM Resorts International Buyer Propensity']
# - ['Travel', 'Specialty Travel']
# - ['Travel', 'Future Travel']
# - ['Travel', 'Travel Guides and Travelogues']
# - ['Travel', 'Thanksgiving Travel']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Destinations', 'Africa']
# - ['Travel']
# - ['Travel', 'Travel']
# - ['Travel', 'Budget Travel']
# - ['Travel and Tourism', 'Interest (Affinity)', 'Products', 'Air Travel']
# - ['Travel', 'Tourist Destinations', 'Theme Parks']
# C:\Users\ek102\.conda\envs\audience-segmentation\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\ek102\AppData\Local\Temp\ipykernel_28932\311197928.py:64: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df['cluster_label'] = df.groupby('cluster').apply(generate_cluster_label).reset_index(drop=True)

# %% [markdown]
# ## Label documents with pre-defined labels

# %%
# Initialize model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Categories with related words
categories = {
    "Sports": ["sports", "soccer", "tennis", "basketball", "fitness", "athlete", "game", "team", "player", "workout", "NFL", "UFC"],
    "Finance": ["finance", "investment", "retirement", "planning", "banking", "savings", "stocks", "trading", "budget", "wealth", "credit", "credit card" "mortgage", "insurance"],
    "Entertainment": ["entertainment", "movies", "tv", "music", "streaming", "shows", "film", "concert", "series", "media", "news", "local news", "politics"],
    "Automotive": ["automotive", "car", "vehicle", "buying", "dealer", "maintenance", "repair", "driving", "truck", "road", "motorcycle"],
    "Demographics": ["age", "age", "age", "gender", "demographics", "demo", "population", "segment", "group", "generation", "household", "income", "education", "sociodemographic"],
    "Outdoors": ["outdoors", "nature", "equestrian", "hiking", "camping", "adventure", "wildlife", "trail", "park", "wilderness"],
    "Travel": ["travel", "tourism", "vacation", "trip", "destination", "flight", "hotel", "resort", "cruise", "journey", "airlines"],
    "Food and Drink": ["food", "drink", "cuisine", "restaurant", "cooking", "recipe", "dining", "gourmet", "snack", "meal", "flavor", "nutrition"],
    "Style": ["fashion", "clothing", "accessories", "trends", "design", "outfit", "wardrobe", "couture", "runway", "beauty"],
    "Technology": ["technology", "gadgets", "software", "smartphone" "hardware", "innovation", "device", "digital", "electronics", "AI", "tech", "internet", "telecom", "mobile"],
    "Health": ["health", "wellness", "nutrition", "medical", "disease", "treatment", "exercise", "therapy", "prevention", "mental health", "fitness"],
    "Beauty": ["beauty", "cosmetics", "skincare", "makeup", "grooming", "aesthetics", "fragrance", "personal care", "salon"],
    "Home Goods": ["home", "furniture", "decor", "appliances", "bedding", "kitchenware", "interior", "garden", "accessories", "living space"],
    "Relationships": ["relationship", "dating", "marriage", "family", "friendship", "connection", "partnership", "community"],
    "Education": ["education", "learning", "school", "college", "university", "courses", "teaching", "training", "study", "knowledge"],
    "Pets": ["pets", "dogs", "cats", "animal", "care", "training", "grooming", "veterinary", "adoption", "pet supplies"],
    "Real Estate": ["real estate", "property", "housing", "homeownership", "rental", "mortgage", "realty", "land", "development"],
    "B2B": ["B2B", "business to business", "B2B decision maker", "enterprise", "commercial", "client relations"],
    "Life Events": ["life event", "new parent", "job search", "graduation", "movers", "retirement", "marriage", "divorce", "military"],
    "Public Services": ["law and government", "public safety", "military", "government", "legal", "insurance", "emergency services"]
}

def apply_position_weights(tokens, weight_factor):
    """Apply position-based weights to tokens, giving more weight to later tokens"""
    if isinstance(tokens, str):
        tokens = tokens.split()

    n = len(tokens)
    if n == 0:
        return ""

    # Calculate weights for each position
    # Later positions get higher weights
    weights = [1 + (i * weight_factor) for i in range(n)]

    # Repeat tokens based on their weights
    weighted_tokens = []
    for token, weight in zip(tokens, weights):
        # Round weight to nearest integer and repeat token that many times
        repeats = max(1, round(weight))
        weighted_tokens.extend([token] * repeats)

    return " ".join(weighted_tokens)

def calculate_category_embeddings(categories, weight_factor):
    """Calculate embeddings for each category by combining all keywords"""
    category_embeddings = {}
    for category, keywords in categories.items():
        # Apply position weights to keywords
        weighted_text = apply_position_weights(keywords, weight_factor)
        category_embeddings[category] = model.encode(weighted_text, convert_to_tensor=True)
    return category_embeddings

def assign_best_category(tokens, category_embeddings, threshold, weight_factor):
    """Assign category based on cosine similarity with threshold"""
    if not tokens:  # Handle empty tokens
        return "Other"

    # Apply position weights to input tokens
    if isinstance(tokens, list):
        weighted_text = apply_position_weights(tokens, weight_factor)
    else:
        weighted_text = apply_position_weights(str(tokens), weight_factor)

    # Generate document embedding
    doc_embedding = model.encode(weighted_text, convert_to_tensor=True)

    # Calculate similarities with all categories
    similarities = {}
    for category, cat_embedding in category_embeddings.items():
        similarity = util.pytorch_cos_sim(doc_embedding, cat_embedding).item()
        similarities[category] = similarity

    # Find best match
    best_category = max(similarities.items(), key=lambda x: x[1])

    # Return best category if above threshold, otherwise "Other"
    if best_category[1] >= threshold:
        return best_category[0]
    return "Other"

def classify_segments(df, min_threshold=0.3, weight_factor=0.1):
    """Main function to classify all segments in the dataframe"""
    # Calculate category embeddings once with weight factor
    category_embeddings = calculate_category_embeddings(categories, weight_factor)

    # Apply classification to each row with weight factor
    df['assigned_category'] = df['tokens'].apply(
        lambda x: assign_best_category(x, category_embeddings, min_threshold, weight_factor)
    )

    return df

def display_categories(df):
    # Calculate the percentage of labeled rows
    total_rows = len(df)
    labeled_rows = len(df[df['assigned_category'] != 'Other'])
    pct_labeled = (labeled_rows / total_rows) * 100 if total_rows > 0 else 0

    print(f"Labeled: {pct_labeled:.2f}%")

    # Group by assigned category and display segments
    grouped = df.groupby('assigned_category')
    for category, group in grouped:
        print(f"\n{category} ({len(group)} items):")
        for segment in group['Audience Segment']:
            print(f"- {segment}")

df = classify_segments(df, min_threshold=0.225, weight_factor=0.4)
# display_categories(df)

# %%
# Rename column 'assigned_category' to 'Audience Segment - Label'
df.rename(columns={'assigned_category': 'Audience Segment - Label'}, inplace=True)

# Drop 'tokens' column
df.drop(columns=['tokens', 'weighted_embeddings', 'cluster', 'cluster_label'], inplace=True)

# Move 'Audience Segment - Label' column to next to original 'Audience Segment' column
columns = df.columns.tolist()

audience_segment_index = columns.index('Audience Segment')
columns.insert(audience_segment_index + 1, columns.pop(columns.index('Audience Segment - Label')))

df = df[columns]

# %%
# Final check
df.head()
# Out:
#                                     Audience Segment Audience Segment - Label  \
# 0  Online Behavior > United States > Validated De...             Demographics
# 1  Online Behavior > United States > Finance > Fi...                  Finance
# 2  Online Behavior > United States > Hobbies and ...                 Outdoors
# 3  Online Behavior > United States > Intent > Aut...               Automotive
# 4  Online Behavior > United States > Beauty and F...                   Health
#
#   Creative Size              Creative Messaging  \
# 0       300x250  Subscribe Today - 10% Discount
# 1        320x50         Sign up Today - 10% Off
# 2       300x250  Subscribe Today - 10% Discount
# 3       300x250           Sign up Now - 10% Off
# 4       300x250           Sign up Now - 10% Off
#
#                            Location          App/URL  \
# 0           Los Angeles, California   abcnews.go.com
# 1    Orlando-Daytona Beach, Florida  accuweather.com
# 2         San Francisco, California  accuweather.com
# 3  Grand Rapids-Kalamazoo, Michigan  accuweather.com
# 4                 Chicago, Illinois  accuweather.com
#
#                           Exchange Device Make Impressions  Clicks  \
# 0                Google Ad Manager    Apple PC       10524    55.0
# 1                         PubMatic  Smartphone       18324    60.0
# 2                Google Ad Manager  Smartphone        7862    20.0
# 3  Xandr - Monetize SSP (AppNexus)  Smartphone       10501    90.0
# 4                      Magnite DV+    Apple PC       23156    73.0
#
#   Viewable Impressions Measurable Impressions  Total Conversions   Gross Cost
# 0                 7601                  10242               11.0  6136.133902
# 1                 3145                  13703                8.0  6996.231838
# 2                 2152                   6039                2.0  6506.433687
# 3                 4126                   7654                8.0  6244.517921
# 4                 4468                  18821               15.0  6173.412890

# %%
# Save labeled data to CSV
df.to_csv('data_cleaned.csv', index=False)
